# %%
# Sales Data Calculator
# Day 4 - AI & ML Internship

# Sales data
sales = [12000, 18500, 15000, 22000, 17500, 25000, 14000, 19500]

# Calculate sales statistics
total_sales = sum(sales)
average_sales = total_sales / len(sales)
highest_sale = max(sales)
lowest_sale = min(sales)

# Display results
print("Sales Data Calculator")
print("---------------------")
print("Sales Values:", sales)
print("Total Sales:", total_sales)
print("Average Sales:", average_sales)
print("Highest Sale:", highest_sale)
print("Lowest Sale:", lowest_sale)
# Out:
# Sales Data Calculator
# ---------------------
# Sales Values: [12000, 18500, 15000, 22000, 17500, 25000, 14000, 19500]
# Total Sales: 143500
# Average Sales: 17937.5
# Highest Sale: 25000
# Lowest Sale: 12000
